# %% [markdown]
# # Workshop 4: Linear Regression

# %% [markdown]
# ## 1. Plotting a line

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1.1 Two Point Method

# %%
# Directly run
xmin, xmax, ymin, ymax = -5, 5, -5, 5
ticks_frequency = 1
fig, ax = plt.subplots(figsize=(10, 10))
ax.set(xlim=(xmin-1, xmax+1), ylim=(ymin-1, ymax+1), aspect='equal')# Set identical scales for both axes
ax.spines['bottom'].set_position('zero') # Set bottom and left spines as x and y axes of coordinate system
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False) # Remove top and right spines
ax.spines['right'].set_visible(False)
ax.set_xlabel('x', size=14, labelpad=-24, x=1.03) # Create 'x' and 'y' labels placed at the end of the axes
ax.set_ylabel('y', size=14, labelpad=-21, y=1.02, rotation=0)
x_ticks = np.arange(xmin, xmax+1, ticks_frequency) # Create custom major ticks to determine position of tick labels
y_ticks = np.arange(ymin, ymax+1, ticks_frequency)
ax.set_xticks(x_ticks[x_ticks != 0])
ax.set_yticks(y_ticks[y_ticks != 0])
ax.set_xticks(np.arange(xmin, xmax+1), minor=True)
ax.set_yticks(np.arange(ymin, ymax+1), minor=True)
ax.grid(which='both', color='grey', linewidth=1, linestyle='-', alpha=0.2) # Draw major and minor grid lines
arrow_fmt = dict(markersize=4, color='black', clip_on=False)  # Draw arrows
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)



x = [3,-4]
y = [4,-2]
plt.scatter(x,y,c="r")
plt.plot(x,y)


plt.show()

# %% [markdown]
# ### 1.2 Slope and Bias Method

# %%
# Directly run
xmin, xmax, ymin, ymax = -5, 5, -5, 5
ticks_frequency = 1
fig, ax = plt.subplots(figsize=(10, 10))
ax.set(xlim=(xmin-1, xmax+1), ylim=(ymin-1, ymax+1), aspect='equal')# Set identical scales for both axes
ax.spines['bottom'].set_position('zero') # Set bottom and left spines as x and y axes of coordinate system
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False) # Remove top and right spines
ax.spines['right'].set_visible(False)
ax.set_xlabel('x', size=14, labelpad=-24, x=1.03) # Create 'x' and 'y' labels placed at the end of the axes
ax.set_ylabel('y', size=14, labelpad=-21, y=1.02, rotation=0)
x_ticks = np.arange(xmin, xmax+1, ticks_frequency) # Create custom major ticks to determine position of tick labels
y_ticks = np.arange(ymin, ymax+1, ticks_frequency)
ax.set_xticks(x_ticks[x_ticks != 0])
ax.set_yticks(y_ticks[y_ticks != 0])
ax.set_xticks(np.arange(xmin, xmax+1), minor=True)
ax.set_yticks(np.arange(ymin, ymax+1), minor=True)
ax.grid(which='both', color='grey', linewidth=1, linestyle='-', alpha=0.2) # Draw major and minor grid lines
arrow_fmt = dict(markersize=4, color='black', clip_on=False)  # Draw arrows
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)



slope_1 = 1
slope_2 = 0.5
bias = 2   # y = slope * x + bias

x = np.array([-5,5])
y1 = x*slope_1 + bias
y2 = x*slope_2 + bias

plt.plot(x,y1, c="b")
plt.plot(x,y2, c="r")


plt.show()

# %%
# Directly run
xmin, xmax, ymin, ymax = -5, 5, -5, 5
ticks_frequency = 1
fig, ax = plt.subplots(figsize=(10, 10))
ax.set(xlim=(xmin-1, xmax+1), ylim=(ymin-1, ymax+1), aspect='equal')# Set identical scales for both axes
ax.spines['bottom'].set_position('zero') # Set bottom and left spines as x and y axes of coordinate system
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False) # Remove top and right spines
ax.spines['right'].set_visible(False)
ax.set_xlabel('x', size=14, labelpad=-24, x=1.03) # Create 'x' and 'y' labels placed at the end of the axes
ax.set_ylabel('y', size=14, labelpad=-21, y=1.02, rotation=0)
x_ticks = np.arange(xmin, xmax+1, ticks_frequency) # Create custom major ticks to determine position of tick labels
y_ticks = np.arange(ymin, ymax+1, ticks_frequency)
ax.set_xticks(x_ticks[x_ticks != 0])
ax.set_yticks(y_ticks[y_ticks != 0])
ax.set_xticks(np.arange(xmin, xmax+1), minor=True)
ax.set_yticks(np.arange(ymin, ymax+1), minor=True)
ax.grid(which='both', color='grey', linewidth=1, linestyle='-', alpha=0.2) # Draw major and minor grid lines
arrow_fmt = dict(markersize=4, color='black', clip_on=False)  # Draw arrows
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)


slope = 1
bias_1 = 2   # y = slope * x + bias
bias_2 = 3 
bias_3 = 4
bias_4 = 5

x = np.array([-5,5])

y1 = x*slope + bias_1
y2 = x*slope + bias_2
y3 = x*slope + bias_3
y4 = x*slope + bias_4

plt.plot(x,y1, c="b")
plt.plot(x,y2, c="r")
plt.plot(x,y3, c="g")
plt.plot(x,y4, c="orange")

plt.show()

# %%
slope_1 = -1
slope_2 = 1
slope_3 = 3
slope_4 = 0.5

bias = 70

plt.figure(figsize=[4,4])
plt.xlim(-100,100)
plt.ylim(-100,100)

x = [-100,100]
y_1 = []
y_2 = []
y_3 = []
y_4 = []

for i in x:
    y_1.append(i*slope_1+bias)
    y_2.append(i*slope_2+bias)
    y_3.append(i*slope_3+bias)
    y_4.append(i*slope_4+bias)

plt.plot(x,y_1)
plt.plot(x,y_2)
plt.plot(x,y_3)
plt.plot(x,y_4)

# %%
slope = 1

bias_1 = 70
bias_2 = 0
bias_3 = 10
bias_4 = -30

plt.figure(figsize=[4,4])
plt.xlim(-100,100)
plt.ylim(-100,100)

x = [-100,100]
y_1 = []
y_2 = []
y_3 = []
y_4 = []

for i in x:
    y_1.append(i*slope+bias_1)
    y_2.append(i*slope+bias_2)
    y_3.append(i*slope+bias_3)
    y_4.append(i*slope+bias_4)

plt.plot(x,y_1)
plt.plot(x,y_2)
plt.plot(x,y_3)
plt.plot(x,y_4)

# %% [markdown]
# ## 2. Linear Regression

# %% [markdown]
# ### 2.1 Show samples in figure

# %% [markdown]
# #### Exercise 1. Could you collate the following list into the format of X and y?

# %%
Raw_data = [6.1101,  17.5920,
            5.5277,  9.1302,
            8.5186,  13.6620,
            3.2365,  6.4421,
            7.0032,  11.8540,
            5.8598,  6.8233,
            10.9003,  19.7968,
            12.1108, 20.9464,
            2.3355, 4.6102,
            3.4547, 5,
            3.1109, 6.0091,
            3.5789, 7.0903,
            5.2067, 10.9897,
            1.1234, 3.0006,
            1.1518, 3.2035,
            2.2224, 5.0007,
            4.6728, 9.7832,
            3.3398, 7.2893,
            6.1718, 13.1452,
            13.1409, 28.2882,
            11.1112, 23.0405,
            5.1122, 12.3039,
            7.2135, 16.0088]

# %%
# Directly run
xmin, xmax, ymin, ymax = 0, 15, 0, 30
ticks_frequency = 1
fig, ax = plt.subplots(figsize=(10, 10))
ax.set(xlim=(xmin-1, xmax+1), ylim=(ymin-1, ymax+1), aspect='equal')# Set identical scales for both axes
ax.spines['bottom'].set_position('zero') # Set bottom and left spines as x and y axes of coordinate system
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False) # Remove top and right spines
ax.spines['right'].set_visible(False)
ax.set_xlabel('x', size=14, labelpad=-24, x=1.03) # Create 'x' and 'y' labels placed at the end of the axes
ax.set_ylabel('y', size=14, labelpad=-21, y=1.02, rotation=0)
x_ticks = np.arange(xmin, xmax+1, ticks_frequency) # Create custom major ticks to determine position of tick labels
y_ticks = np.arange(ymin, ymax+1, ticks_frequency)
ax.set_xticks(x_ticks[x_ticks != 0])
ax.set_yticks(y_ticks[y_ticks != 0])
ax.set_xticks(np.arange(xmin, xmax+1), minor=True)
ax.set_yticks(np.arange(ymin, ymax+1), minor=True)
ax.grid(which='both', color='grey', linewidth=1, linestyle='-', alpha=0.2) # Draw major and minor grid lines
arrow_fmt = dict(markersize=4, color='black', clip_on=False)  # Draw arrows
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)

X = Raw_data[::2]
y = Raw_data[1::2]

ax.scatter(X,y)
plt.show()

# %% [markdown]
# #### Exercise 2. Could you plot a line whose slope=1 and bias=4 based on the figure above?

# %%
# Directly run
xmin, xmax, ymin, ymax = 0, 15, 0, 30
ticks_frequency = 1
fig, ax = plt.subplots(figsize=(10, 10))
ax.set(xlim=(xmin-1, xmax+1), ylim=(ymin-1, ymax+1), aspect='equal')# Set identical scales for both axes
ax.spines['bottom'].set_position('zero') # Set bottom and left spines as x and y axes of coordinate system
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False) # Remove top and right spines
ax.spines['right'].set_visible(False)
ax.set_xlabel('x', size=14, labelpad=-24, x=1.03) # Create 'x' and 'y' labels placed at the end of the axes
ax.set_ylabel('y', size=14, labelpad=-21, y=1.02, rotation=0)
x_ticks = np.arange(xmin, xmax+1, ticks_frequency) # Create custom major ticks to determine position of tick labels
y_ticks = np.arange(ymin, ymax+1, ticks_frequency)
ax.set_xticks(x_ticks[x_ticks != 0])
ax.set_yticks(y_ticks[y_ticks != 0])
ax.set_xticks(np.arange(xmin, xmax+1), minor=True)
ax.set_yticks(np.arange(ymin, ymax+1), minor=True)
ax.grid(which='both', color='grey', linewidth=1, linestyle='-', alpha=0.2) # Draw major and minor grid lines
arrow_fmt = dict(markersize=4, color='black', clip_on=False)  # Draw arrows
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)

X = Raw_data[::2]
y = Raw_data[1::2]
slope = 1
bias = 4
y_pred=[]
for i in X:
    y_pred.append(i*slope+bias)

ax.scatter(X,y)
ax.plot(X,y_pred,c="r")
plt.show()

# %% [markdown]
# ### 2.2 Calculate the loss
# Here we will compute the cost function and code that into Python. Cost function is given by
# $$
# J\left(\theta_0, \theta_1\right)=\frac{1}{2 m} \sum_{i=1}^m\left(h_\theta\left(x_i\right)-y_i\right)^2
# $$
# Where $h_\theta(x_i) = \theta_1 x_i + \theta_0$

# %%
y_sub = []
for i in range(len(y)):
    y_sub.append((y_pred[i] - y[i])**2)

0.5*sum(y_sub)/len(y_sub)
# Out:
# 8.02611939152174

# %% [markdown]
# #### 2.2.1 Plot the loss curve when bias is fixed.

# %%
slope_list = [i*0.1 for i in range(0,100)]
bias = 4

plt.figure(figsize=[4,4])
plt.xlim(0,5)
plt.ylim(0,10)

plt.title("Loss Curve")
plt.xlabel("Slope")
plt.ylabel("loss")

slope_loss_list=[]
for slope in slope_list:
    y_pred = []
    for i in X:
        y_pred.append(i*slope+bias)

    y_sub = []
    for i in range(len(y)):
        y_sub.append((y_pred[i] - y[i])**2)
    slope_loss_list.append(sum(y_sub)/2/len(y))

plt.plot([i*0.1 for i in range(100)],slope_loss_list)

# %% [markdown]
# #### Exercise 3. Could you plot the loss curve when slope is fixed?

# %%
slope = 1
bias_list = [i*0.1 for i in range(100)]

plt.figure(figsize=[4,4])
plt.xlim(0,10)
plt.ylim(0,1000)

plt.title("Loss Curve")
plt.xlabel("bias")
plt.ylabel("loss")

bias_loss_list=[]
for bias in bias_list:
    y_pred = []
    for i in X:
        y_pred.append(i*slope+bias)

    y_sub = []
    for i in range(len(y)):
        y_sub.append((y_pred[i] - y[i])**2)
    bias_loss_list.append(sum(y_sub))

plt.plot([i*0.1 for i in range(100)],bias_loss_list)

# %% [markdown]
# ### 2.3 Gradient Descent
#
# $$
# \begin{aligned}
# \theta_0 &:=\theta_0-\alpha \frac{1}{m} \sum_{i=1}^m\left[\left(h_\theta\left(x_i\right)-y_i\right) x_i^{(0)}\right] \\
# \theta_1 &:=\theta_1-\alpha \frac{1}{m} \sum_{i=1}^m\left[\left(h_{\theta}\left(x_i\right)-y_i\right) x_i^{(1)}\right]
# \end{aligned}
# $$

# %%
# Directly run
xmin, xmax, ymin, ymax = 0, 15, 0, 30
ticks_frequency = 1
fig, ax = plt.subplots(figsize=(10, 10))
ax.set(xlim=(xmin-1, xmax+1), ylim=(ymin-1, ymax+1), aspect='equal')# Set identical scales for both axes
ax.spines['bottom'].set_position('zero') # Set bottom and left spines as x and y axes of coordinate system
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False) # Remove top and right spines
ax.spines['right'].set_visible(False)
ax.set_xlabel('x', size=14, labelpad=-24, x=1.03) # Create 'x' and 'y' labels placed at the end of the axes
ax.set_ylabel('y', size=14, labelpad=-21, y=1.02, rotation=0)
x_ticks = np.arange(xmin, xmax+1, ticks_frequency) # Create custom major ticks to determine position of tick labels
y_ticks = np.arange(ymin, ymax+1, ticks_frequency)
ax.set_xticks(x_ticks[x_ticks != 0])
ax.set_yticks(y_ticks[y_ticks != 0])
ax.set_xticks(np.arange(xmin, xmax+1), minor=True)
ax.set_yticks(np.arange(ymin, ymax+1), minor=True)
ax.grid(which='both', color='grey', linewidth=1, linestyle='-', alpha=0.2) # Draw major and minor grid lines
arrow_fmt = dict(markersize=4, color='black', clip_on=False)  # Draw arrows
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)

X = Raw_data[::2]
y = Raw_data[1::2]
slope = 1
bias = 4
y_pred=[]
for i in X:
    y_pred.append(i*slope+bias)

ax.scatter(X,y)
ax.plot(X,y_pred,c="r")
plt.show()

# %% [markdown]
# #### 2.3.1 Fixed slope, varying bias

# %%
# Directly run
xmin, xmax, ymin, ymax = 0, 15, 0, 30
ticks_frequency = 1
fig, ax = plt.subplots(figsize=(10, 10))
ax.set(xlim=(xmin-1, xmax+1), ylim=(ymin-1, ymax+1), aspect='equal')# Set identical scales for both axes
ax.spines['bottom'].set_position('zero') # Set bottom and left spines as x and y axes of coordinate system
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False) # Remove top and right spines
ax.spines['right'].set_visible(False)
ax.set_xlabel('x', size=14, labelpad=-24, x=1.03) # Create 'x' and 'y' labels placed at the end of the axes
ax.set_ylabel('y', size=14, labelpad=-21, y=1.02, rotation=0)
x_ticks = np.arange(xmin, xmax+1, ticks_frequency) # Create custom major ticks to determine position of tick labels
y_ticks = np.arange(ymin, ymax+1, ticks_frequency)
ax.set_xticks(x_ticks[x_ticks != 0])
ax.set_yticks(y_ticks[y_ticks != 0])
ax.set_xticks(np.arange(xmin, xmax+1), minor=True)
ax.set_yticks(np.arange(ymin, ymax+1), minor=True)
ax.grid(which='both', color='grey', linewidth=1, linestyle='-', alpha=0.2) # Draw major and minor grid lines
arrow_fmt = dict(markersize=4, color='black', clip_on=False)  # Draw arrows
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)

X = Raw_data[::2]
y = Raw_data[1::2]
slope = 1
bias = 4

alpha=0.0001
loss_list=[]
for iteration in range(10000):
    y_pred = []
    for i in X:
        y_pred.append(i*slope+bias)

    bias_samples_gradient_list = []
    for i in range(len(X)):
        bias_one_sample_gradient = slope*X[i]+bias-y[i]
        bias_samples_gradient_list.append(bias_one_sample_gradient)
    bias-=alpha*sum(bias_samples_gradient_list)

y_pred=[]
for i in X:
    y_pred.append(i*slope+bias)

ax.scatter(X,y)
ax.plot(X,y_pred,c="r")
plt.show()

# %% [markdown]
# #### 2.3.1 Fixed bias, varying slope

# %%
# Directly run
xmin, xmax, ymin, ymax = 0, 15, 0, 30
ticks_frequency = 1
fig, ax = plt.subplots(figsize=(10, 10))
ax.set(xlim=(xmin-1, xmax+1), ylim=(ymin-1, ymax+1), aspect='equal')# Set identical scales for both axes
ax.spines['bottom'].set_position('zero') # Set bottom and left spines as x and y axes of coordinate system
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False) # Remove top and right spines
ax.spines['right'].set_visible(False)
ax.set_xlabel('x', size=14, labelpad=-24, x=1.03) # Create 'x' and 'y' labels placed at the end of the axes
ax.set_ylabel('y', size=14, labelpad=-21, y=1.02, rotation=0)
x_ticks = np.arange(xmin, xmax+1, ticks_frequency) # Create custom major ticks to determine position of tick labels
y_ticks = np.arange(ymin, ymax+1, ticks_frequency)
ax.set_xticks(x_ticks[x_ticks != 0])
ax.set_yticks(y_ticks[y_ticks != 0])
ax.set_xticks(np.arange(xmin, xmax+1), minor=True)
ax.set_yticks(np.arange(ymin, ymax+1), minor=True)
ax.grid(which='both', color='grey', linewidth=1, linestyle='-', alpha=0.2) # Draw major and minor grid lines
arrow_fmt = dict(markersize=4, color='black', clip_on=False)  # Draw arrows
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)

X = Raw_data[::2]
y = Raw_data[1::2]
slope = 1
bias = 4

alpha=0.0001
loss_list=[]
for iteration in range(2000):
    y_pred = []
    for i in X:
        y_pred.append(i*slope+bias)

    slope_samples_gradient_list = []
    for i in range(len(X)):
        slope_one_sample_gradient = (slope*X[i]+bias-y[i])*X[i]
        slope_samples_gradient_list.append(slope_one_sample_gradient)
    slope-=alpha*sum(slope_samples_gradient_list)

y_pred=[]
for i in X:
    y_pred.append(i*slope+bias)

ax.scatter(X,y)
ax.plot(X,y_pred,c="r")
plt.show()

# %%
alpha=0.0001
loss_list=[]
for iteration in range(100):

    y_pred = []
    for i in X:
        y_pred.append(i*slope+bias)
    y_sub = []
    for i in range(len(y)):
        y_sub.append((y_pred[i] - y[i])**2)
    loss_list.append(sum(y_sub))

    slope_samples_gradient_list = []
    for i in range(len(X)):
        slope_one_sample_gradient = (slope*X[i]+bias-y[i])*X[i]
        slope_samples_gradient_list.append(slope_one_sample_gradient)
    slope-=alpha*sum(slope_samples_gradient_list)

    bias_samples_gradient_list = []
    for i in range(len(X)):
        bias_one_sample_gradient = slope*X[i]+bias-y[i]
        bias_samples_gradient_list.append(bias_one_sample_gradient)
    bias-=alpha*sum(bias_samples_gradient_list)

# %%
plt.figure(figsize=[4,4])
plt.xlim(0,14)
plt.ylim(0,30)

y_pred = []
for i in X:
    y_pred.append(i*slope+bias)

plt.scatter(x=X, y=y)
plt.plot(X,y_pred,color="red")

# %%
plt.plot(loss_list,color="red")
